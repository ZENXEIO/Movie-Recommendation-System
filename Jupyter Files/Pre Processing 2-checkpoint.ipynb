# %%
import pandas as pd
import numpy as np

# %%
credits = pd.read_csv('credits.csv')
credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
meta = pd.read_csv('movies_metadata.csv')
meta.head()
# Out:
# C:\Users\abhin\AppData\Local\Temp\ipykernel_14864\2903413914.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta = pd.read_csv('movies_metadata.csv')
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
# ...

# %%
meta['release_date'] = pd.to_datetime(meta['release_date'], errors='coerce')

# %%
meta['year'] = meta['release_date'].dt.year

# %%
meta['year'].value_counts().sort_index()
# Out:
# 1874.0       1
# 1878.0       1
# 1883.0       1
# 1887.0       1
# 1888.0       2
#           ...
# 2015.0    1905
# 2016.0    1604
# 2017.0     532
# 2018.0       5
# 2020.0       1
# Name: year, Length: 135, dtype: int64

# %%
new_meta = meta.loc[meta.year == 2017, ['genres', 'id','title','year']]
new_meta.head()
# Out:
#                                                   genres      id  \
# 26560  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...  166426
# 26561  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  141052
# 26565  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  284053
# 26566  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  283995
# 30536  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...  245842
#
#                                                   title    year
# 26560  Pirates of the Caribbean: Dead Men Tell No Tales  2017.0
# 26561                                    Justice League  2017.0
# 26565                                    Thor: Ragnarok  2017.0
# 26566                    Guardians of the Galaxy Vol. 2  2017.0
# 30536                               The King's Daughter  2017.0

# %%
new_meta['id'] = new_meta['id'].astype(int)

# %%
data = pd.merge(new_meta, credits, on = 'id')

# %%
pd.set_option('display.max_colwidth', 75)
data.head(30)
# Out:
#                                                                         genres  \
# 0   [{'id': 12, 'name': 'Adventure'}, {'id': 28, 'name': 'Action'}, {'id': ...
# 1   [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': ...
# 2   [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': ...
# 3   [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': ...
# 4   [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'name': 'Action'}, {'id': 12...
# 5            [{'id': 53, 'name': 'Thriller'}, {'id': 12, 'name': 'Adventure'}]
# 6                  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}]
# 7   [{'id': 28, 'name': 'Action'}, {'id': 14, 'name': 'Fantasy'}, {'id': 87...
# 8                                               [{'id': 35, 'name': 'Comedy'}]
# 9   [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': ...
# 10  [{'id': 16, 'name': 'Animation'}, {'id': 12, 'name': 'Adventure'}, {'id...
# ...

# %%
data['genres'].dtype
# Out:
# dtype('O')

# %%
import ast

## This will convert string values to list

data['genres'] = data['genres'].map(lambda x: ast.literal_eval(x))
data['cast'] = data['cast'].map(lambda x: ast.literal_eval(x))
data['crew'] = data['crew'].map(lambda x: ast.literal_eval(x))

# %%
data['genres'].dtype
# Out:
# dtype('O')

# %%
def make_genre_list(x):
    gen = []
    st = " "
    for i in x:
        if i.get('name') == 'Science Fiction':
            scifi = 'Sci-Fi'
            gen.append(scifi)
        else:
            gen.append(i.get('name'))
    if gen == []:
        return np.NaN
    else:
        return(st.join(gen))

# %%
data['genres_list'] = data['genres'].map(lambda x: make_genre_list(x))

# %%
data['genres_list']
# Out:
# 0      Adventure Action Fantasy Comedy
# 1      Action Adventure Fantasy Sci-Fi
# 2      Action Adventure Fantasy Sci-Fi
# 3       Action Adventure Comedy Sci-Fi
# 4             Fantasy Action Adventure
#                     ...
# 526                     Romance Comedy
# 527         Crime Comedy Action Family
# 528    Family Animation Romance Comedy
# 529               Crime Drama Thriller
# 530                                NaN
# Name: genres_list, Length: 531, dtype: object

# %%
def get_actor1(x):
    cast = []
    for i in x:
        cast.append(i.get('name'))
    if cast == []:
        return np.NaN
    else:
        return(cast[0])

# %%
for i in data.columns:
    print(i)
# Out:
# genres
# id
# title
# year
# cast
# crew
# genres_list

# %%
data['actor_1_name'] = data['cast'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    cast = []
    for i in x:
        cast.append(i.get('name'))
    if cast == [] or len(cast)<=1:
        return np.NaN
    else:
        return(cast[1])

# %%
data['actor_2_name'] = data['cast'].map(lambda x: get_actor2(x))

# %%
data['actor_2_name']
# Out:
# 0       Javier Bardem
# 1        Henry Cavill
# 2      Tom Hiddleston
# 3         Zoe Saldana
# 4        William Hurt
#             ...
# 526     Rosa Honkonen
# 527     Wallace Shawn
# 528               NaN
# 529         Sajal Ali
# 530               NaN
# Name: actor_2_name, Length: 531, dtype: object

# %%
data['actor_1_name']
# Out:
# 0               Johnny Depp
# 1               Ben Affleck
# 2           Chris Hemsworth
# 3               Chris Pratt
# 4            Pierce Brosnan
#                ...
# 526          Inka Haapamäki
# 527    Lou Diamond Phillips
# 528                     NaN
# 529          Sridevi Kapoor
# 530                     NaN
# Name: actor_1_name, Length: 531, dtype: object

# %%
def get_actor3(x):
    cast = []
    for i in x:
        cast.append(i.get('name'))
    if cast == [] or len(cast)<=2:
        return np.NaN
    else:
        return(cast[2])

# %%
data['actor_3_name'] = data['cast'].map(lambda x: get_actor3(x))

# %%
data['actor_3_name']
# Out:
# 0        Geoffrey Rush
# 1            Gal Gadot
# 2       Cate Blanchett
# 3        Dave Bautista
# 4      Benjamin Walker
#             ...
# 526     Tiitus Rantala
# 527        Gina Holden
# 528                NaN
# 529     Akshaye Khanna
# 530                NaN
# Name: actor_3_name, Length: 531, dtype: object

# %%
def get_directors(x):
    dt = []
    st =" "
    for i in x:
        if i.get('job') == 'Director':
            dt.append(i.get('name'))
    if dt == []:
        return np.NaN
    else:
        return(st.join(dt))

# %%
data['director_name'] = data['crew'].map(lambda x: get_directors(x))

# %%
data['director_name']
# Out:
# 0      Joachim Rønning Espen Sandberg
# 1                         Zack Snyder
# 2                       Taika Waititi
# 3                          James Gunn
# 4                       Sean McNamara
#                     ...
# 526                  Hannaleena Hauru
# 527             Jonathan A. Rosenbaum
# 528          Beth David Esteban Bravo
# 529                      Ravi Udyawar
# 530                     Daisy Asquith
# Name: director_name, Length: 531, dtype: object

# %%
for i in data.columns:
    print(i)
# Out:
# genres
# id
# title
# year
# cast
# crew
# genres_list
# actor_1_name
# actor_2_name
# actor_3_name
# director_name

# %%
new_movie_set = data.loc[:,['title','genres_list','director_name', 'actor_1_name','actor_2_name','actor_3_name']]

# %%
new_movie_set.head()
# Out:
#                                               title  \
# 0  Pirates of the Caribbean: Dead Men Tell No Tales
# 1                                    Justice League
# 2                                    Thor: Ragnarok
# 3                    Guardians of the Galaxy Vol. 2
# 4                               The King's Daughter
#
#                        genres_list                   director_name  \
# 0  Adventure Action Fantasy Comedy  Joachim Rønning Espen Sandberg
# 1  Action Adventure Fantasy Sci-Fi                     Zack Snyder
# 2  Action Adventure Fantasy Sci-Fi                   Taika Waititi
# 3   Action Adventure Comedy Sci-Fi                      James Gunn
# 4         Fantasy Action Adventure                   Sean McNamara
#
#       actor_1_name    actor_2_name     actor_3_name
# 0      Johnny Depp   Javier Bardem    Geoffrey Rush
# 1      Ben Affleck    Henry Cavill        Gal Gadot
# 2  Chris Hemsworth  Tom Hiddleston   Cate Blanchett
# ...

# %%
new_movie_set.isna().sum()
# Out:
# title             0
# genres_list       7
# director_name     4
# actor_1_name     22
# actor_2_name     55
# actor_3_name     70
# dtype: int64

# %%
new_movie_set = new_movie_set.dropna(how = 'any')

# %%
new_movie_set.rename({'genres_list': 'genres'}, axis=1, inplace=True)
#new_movie_set['genres_list']

# %%
new_movie_set.rename({'title': 'movie_title'}, axis=1, inplace=True)

# %%
new_movie_set.head()
# Out:
#                                         movie_title  \
# 0  Pirates of the Caribbean: Dead Men Tell No Tales
# 1                                    Justice League
# 2                                    Thor: Ragnarok
# 3                    Guardians of the Galaxy Vol. 2
# 4                               The King's Daughter
#
#                             genres                   director_name  \
# 0  Adventure Action Fantasy Comedy  Joachim Rønning Espen Sandberg
# 1  Action Adventure Fantasy Sci-Fi                     Zack Snyder
# 2  Action Adventure Fantasy Sci-Fi                   Taika Waititi
# 3   Action Adventure Comedy Sci-Fi                      James Gunn
# 4         Fantasy Action Adventure                   Sean McNamara
#
#       actor_1_name    actor_2_name     actor_3_name
# 0      Johnny Depp   Javier Bardem    Geoffrey Rush
# 1      Ben Affleck    Henry Cavill        Gal Gadot
# 2  Chris Hemsworth  Tom Hiddleston   Cate Blanchett
# ...

# %%
new_movie_set['movie_title'] = new_movie_set['movie_title'].str.lower()

# %%
new_movie_set['Tags'] = new_movie_set['actor_1_name'] + ' ' + new_movie_set['actor_2_name'] + ' ' + new_movie_set['actor_3_name']+ ' ' + new_movie_set['director_name'] + ' ' + new_movie_set['genres']

# %%
new_movie_set
# Out:
#                                           movie_title  \
# 0    pirates of the caribbean: dead men tell no tales
# 1                                      justice league
# 2                                      thor: ragnarok
# 3                      guardians of the galaxy vol. 2
# 4                                 the king's daughter
# ..                                                ...
# 524                      the incredible jessica james
# 525                                 can't buy my love
# 526                  thick lashes of lauri mäntyvaara
# 527                       cop and a half: new recruit
# 529                                               mom
#
#                               genres                   director_name  \
# 0    Adventure Action Fantasy Comedy  Joachim Rønning Espen Sandberg
# 1    Action Adventure Fantasy Sci-Fi                     Zack Snyder
# 2    Action Adventure Fantasy Sci-Fi                   Taika Waititi
# ...

# %%
old = pd.read_csv('Data1.csv')

# %%
old.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker               Unknown
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# 1         Action Adventure Fantasy
# 2        Action Adventure Thriller
# 3                  Action Thriller
# 4                      Documentary
#
#                                               movie_title
# 0                                                  avatar
# 1                pirates of the caribbean: at world's end
# 2                                                 spectre
# ...

# %%
new = old.append(new_movie_set)
# Out:
# C:\Users\abhin\AppData\Local\Temp\ipykernel_14864\1445594904.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new = old.append(new_movie_set)

# %%
new
# Out:
#              director_name          actor_1_name            actor_2_name  \
# 0            James Cameron           CCH Pounder        Joel David Moore
# 1           Gore Verbinski           Johnny Depp           Orlando Bloom
# 2               Sam Mendes       Christoph Waltz            Rory Kinnear
# 3        Christopher Nolan             Tom Hardy          Christian Bale
# 4              Doug Walker           Doug Walker              Rob Walker
# ..                     ...                   ...                     ...
# 524            Jim Strouse      Jessica Williams            Chris O'Dowd
# 525            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 526       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 527  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 529           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#              actor_3_name                           genres  \
# ...

# %%
new.drop_duplicates(subset ='movie_title', keep = 'last', inplace=True)

# %%
new
# Out:
#              director_name          actor_1_name            actor_2_name  \
# 0            James Cameron           CCH Pounder        Joel David Moore
# 1           Gore Verbinski           Johnny Depp           Orlando Bloom
# 2               Sam Mendes       Christoph Waltz            Rory Kinnear
# 3        Christopher Nolan             Tom Hardy          Christian Bale
# 4              Doug Walker           Doug Walker              Rob Walker
# ..                     ...                   ...                     ...
# 524            Jim Strouse      Jessica Williams            Chris O'Dowd
# 525            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 526       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 527  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 529           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#              actor_3_name                           genres  \
# ...

# %%
new.isna().sum()
# Out:
# director_name       0
# actor_1_name        0
# actor_2_name        0
# actor_3_name        0
# genres              0
# movie_title         0
# Tags             4906
# dtype: int64

# %%
new.shape, new_movie_set.shape
# Out:
# ((5364, 7), (458, 7))

# %%
new
# Out:
#              director_name          actor_1_name            actor_2_name  \
# 0            James Cameron           CCH Pounder        Joel David Moore
# 1           Gore Verbinski           Johnny Depp           Orlando Bloom
# 2               Sam Mendes       Christoph Waltz            Rory Kinnear
# 3        Christopher Nolan             Tom Hardy          Christian Bale
# 4              Doug Walker           Doug Walker              Rob Walker
# ..                     ...                   ...                     ...
# 524            Jim Strouse      Jessica Williams            Chris O'Dowd
# 525            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 526       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 527  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 529           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#              actor_3_name                           genres  \
# ...

# %%
new.drop(new.columns[-1], axis=1, inplace=True)

# %%
new
# Out:
#              director_name          actor_1_name            actor_2_name  \
# 0            James Cameron           CCH Pounder        Joel David Moore
# 1           Gore Verbinski           Johnny Depp           Orlando Bloom
# 2               Sam Mendes       Christoph Waltz            Rory Kinnear
# 3        Christopher Nolan             Tom Hardy          Christian Bale
# 4              Doug Walker           Doug Walker              Rob Walker
# ..                     ...                   ...                     ...
# 524            Jim Strouse      Jessica Williams            Chris O'Dowd
# 525            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 526       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 527  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 529           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#              actor_3_name                           genres  \
# ...

# %%
new['Tags'] = new['actor_1_name'] + ' ' + new['actor_2_name'] + ' ' + new['actor_3_name']+ ' ' + new['director_name'] + ' ' + new['genres']

# %%
new
# Out:
#              director_name          actor_1_name            actor_2_name  \
# 0            James Cameron           CCH Pounder        Joel David Moore
# 1           Gore Verbinski           Johnny Depp           Orlando Bloom
# 2               Sam Mendes       Christoph Waltz            Rory Kinnear
# 3        Christopher Nolan             Tom Hardy          Christian Bale
# 4              Doug Walker           Doug Walker              Rob Walker
# ..                     ...                   ...                     ...
# 524            Jim Strouse      Jessica Williams            Chris O'Dowd
# 525            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 526       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 527  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 529           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#              actor_3_name                           genres  \
# ...

# %%
new.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# Tags             0
# dtype: int64

# %%
new.drop_duplicates(subset ='movie_title', keep = 'last', inplace=True)

# %%
new
# Out:
#              director_name          actor_1_name            actor_2_name  \
# 0            James Cameron           CCH Pounder        Joel David Moore
# 1           Gore Verbinski           Johnny Depp           Orlando Bloom
# 2               Sam Mendes       Christoph Waltz            Rory Kinnear
# 3        Christopher Nolan             Tom Hardy          Christian Bale
# 4              Doug Walker           Doug Walker              Rob Walker
# ..                     ...                   ...                     ...
# 524            Jim Strouse      Jessica Williams            Chris O'Dowd
# 525            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 526       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 527  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 529           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#              actor_3_name                           genres  \
# ...

# %%
new.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# Tags             0
# dtype: int64

# %%
new.to_csv('new_data2.csv', index = False)
